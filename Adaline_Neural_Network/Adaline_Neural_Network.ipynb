# %%
# !pip install numpy pandas scikit-learn

# %% [markdown]
# ![image.png](attachment:7cbca8e7-3ea2-4172-ac51-fe4e9e6d818d.png)

# %% [markdown]
# ![image.png](attachment:bea6645e-ecb2-493e-80db-8157637af325.png)

# %% [markdown]
# ![image.png](attachment:38a4f85c-c551-44fe-bba1-dc93f8b38063.png)

# %% [markdown]
# ![image.png](attachment:44d41494-56b8-4ed0-9b13-b9debee0bb03.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
